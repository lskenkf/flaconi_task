# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import re
import os
import warnings
import datetime

import pandas as pd
import numpy as np
import pandasql as psql

from solution import *
from datetime import timedelta
pd.set_option("display.max_rows", None, "display.max_columns", None) # Let pandas print the entire dataframe

# %%
import os
import itertools
import pandas as pd

def get_data(timestamp, input_file):
    timestamp = pd.Timestamp(timestamp)
    data = pd.read_csv(input_file)
    data['time'] = data['time'].apply(
        lambda dt: dt[:-5] + '00:00'
    )
    data['time'] = pd.to_datetime(data['time'])
    data = data.loc[data.time <= timestamp]

    return data


def fill_nan(data):
    data = data.groupby(
        ['device', 'time']
    )['device_activated'].agg(
        'max'
    ).reset_index()

    data = data.set_index(
        ['time', 'device']
    ).unstack(
        fill_value=0
    ).asfreq(
        'H', fill_value=0
    ).stack().sort_index(
        level=1
    ).reset_index()

    return data


def extract_feature(data):
    data['day_name'] = data.time.dt.day_name()
    data['day'] = data.time.dt.day
    data['week'] = data.time.dt.isocalendar().week
    data['hour'] = data.time.dt.hour

    data = data[[
        'device',
        'day_name',
        'hour',
        'device_activated',
        'time'
    ]]
    return data


def data_pipeline(timestamp, input_file):
    data = get_data(timestamp, input_file)
    data = fill_nan(data)
    data = extract_feature(data)

    return data


def get_pred_hash(timestamp, input_file, output_file):
    data = data_pipeline(timestamp, input_file)
    timestamp = pd.Timestamp(timestamp)
    train_data = data[data.time <= timestamp]

    pred_hash = train_data.groupby(
        ['device', 'day_name', 'hour']
    ).agg(
        device_activated=('device_activated', 'max')
    ).reset_index()

    return pred_hash


def generate_prediction_holder(timestamp):
    timestamp = pd.Timestamp(timestamp)
    split_point = timestamp.round(freq='T')
    next_24_hours = pd.date_range(split_point, periods=24, freq='H').ceil('H')
    device_names = ['device_' + str(i) for i in range(1,8)]

    xproduct = list(itertools.product(next_24_hours, device_names))
    prediction_holder = pd.DataFrame(xproduct, columns=['time', 'device'])

    prediction_holder['day_name'] = prediction_holder.time.dt.day_name()
    prediction_holder['hour'] = prediction_holder.time.dt.hour
    columns = [
        'time',
        'device',
        'day_name',
        'hour'
    ]

    prediction_holder = prediction_holder[columns]

    return prediction_holder


def make_pred(timestamp, input_file, output_file):
    pred_hash = get_pred_hash(timestamp, input_file, output_file)
    prediction_holder = generate_prediction_holder(timestamp,pred_hash)
    pred = prediction_holder.merge(pred_hash, how='left', on=['device', 'day_name', 'hour'])
    pred = pred[[
        'time',
        'device',
        'device_activated'
    ]]

    return pred

# %%
timestamp = '2016-07-04 23:59:59'
input_file = 'data\device_activations.csv'
output_file = 'data\myresult.csv'

prediction_holder = generate_prediction_holder(timestamp)

pred_hash = get_pred_hash(timestamp, input_file, output_file)
pred = prediction_holder.merge(pred_hash, how='left', on=['device', 'day_name', 'hour'])
pred = pred.fillna(0)

# %%
prediction_holder.shape, pred_hash.shape,pred.shape
# Out:
# ((168, 4), (528, 4), (168, 5))

# %%
pred_hash
# Out:
#        device  day_name  hour  device_activated
# 0    device_2    Friday     4                 0
# 1    device_2    Friday     5                 0
# 2    device_2    Friday     6                 1
# 3    device_2    Friday     7                 1
# 4    device_2    Friday     8                 1
# 5    device_2    Friday     9                 1
# 6    device_2    Friday    10                 1
# 7    device_2    Friday    11                 1
# 8    device_2    Friday    12                 1
# 9    device_2    Friday    13                 1
# 10   device_2    Friday    14                 1
# 11   device_2    Friday    15                 1
# 12   device_2    Friday    16                 1
# 13   device_2    Friday    17                 0
# 14   device_2    Friday    18                 0
# 15   device_2    Friday    19                 0
# 16   device_2    Friday    20                 0
# 17   device_2    Friday    21                 0
# 18   device_2    Friday    22                 0
# 19   device_2    Friday    23                 0
# 20   device_2    Monday     0                 0
# 21   device_2    Monday     1                 0
# 22   device_2    Monday     2                 0
# 23   device_2    Monday     3                 0
# 24   device_2    Monday     4                 0
# 25   device_2    Monday     5                 0
# 26   device_2    Monday     6                 1
# 27   device_2    Monday     7                 1
# 28   device_2    Monday     8                 1
# 29   device_2    Monday     9                 1
# 30   device_2    Monday    10                 1
# 31   device_2    Monday    11                 1
# 32   device_2    Monday    12                 1
# 33   device_2    Monday    13                 1
# 34   device_2    Monday    14                 1
# 35   device_2    Monday    15                 1
# 36   device_2    Monday    16                 1
# 37   device_2    Monday    17                 1
# 38   device_2    Monday    18                 0
# 39   device_2    Monday    19                 0
# 40   device_2  Saturday     0                 0
# 41   device_2  Saturday     1                 0
# 42   device_2  Saturday     2                 0
# 43   device_2  Saturday     3                 0
# 44   device_2  Saturday     4                 0
# 45   device_2  Saturday     5                 0
# 46   device_2  Saturday     6                 0
# 47   device_2  Saturday     7                 0
# 48   device_2  Saturday     8                 0
# 49   device_2  Saturday     9                 0
# 50   device_2  Saturday    10                 0
# 51   device_2  Saturday    11                 0
# 52   device_2  Saturday    12                 0
# 53   device_2  Saturday    13                 0
# 54   device_2  Saturday    14                 0
# 55   device_2  Saturday    15                 0
# 56   device_2  Saturday    16                 0
# 57   device_2  Saturday    17                 0
# 58   device_2  Saturday    18                 0
# 59   device_2  Saturday    19                 0
# 60   device_2  Saturday    20                 0
# 61   device_2  Saturday    21                 0
# 62   device_2  Saturday    22                 0
# 63   device_2  Saturday    23                 0
# 64   device_2    Sunday     0                 0
# 65   device_2    Sunday     1                 0
# 66   device_2    Sunday     2                 0
# 67   device_2    Sunday     3                 0
# 68   device_2    Sunday     4                 0
# 69   device_2    Sunday     5                 0
# 70   device_2    Sunday     6                 0
# 71   device_2    Sunday     7                 0
# 72   device_2    Sunday     8                 0
# 73   device_2    Sunday     9                 0
# 74   device_2    Sunday    10                 0
# 75   device_2    Sunday    11                 0
# 76   device_2    Sunday    12                 0
# 77   device_2    Sunday    13                 0
# 78   device_2    Sunday    14                 0
# 79   device_2    Sunday    15                 0
# 80   device_2    Sunday    16                 0
# 81   device_2    Sunday    17                 0
# 82   device_2    Sunday    18                 0
# 83   device_2    Sunday    19                 0
# 84   device_2    Sunday    20                 0
# 85   device_2    Sunday    21                 0
# 86   device_2    Sunday    22                 0
# 87   device_2    Sunday    23                 0
# 88   device_3    Friday     4                 0
# 89   device_3    Friday     5                 0
# 90   device_3    Friday     6                 0
# 91   device_3    Friday     7                 0
# 92   device_3    Friday     8                 1
# 93   device_3    Friday     9                 1
# 94   device_3    Friday    10                 1
# 95   device_3    Friday    11                 1
# 96   device_3    Friday    12                 1
# 97   device_3    Friday    13                 1
# 98   device_3    Friday    14                 1
# 99   device_3    Friday    15                 1
# 100  device_3    Friday    16                 0
# 101  device_3    Friday    17                 0
# 102  device_3    Friday    18                 0
# 103  device_3    Friday    19                 0
# 104  device_3    Friday    20                 0
# 105  device_3    Friday    21                 0
# 106  device_3    Friday    22                 0
# 107  device_3    Friday    23                 0
# 108  device_3    Monday     0                 0
# 109  device_3    Monday     1                 0
# 110  device_3    Monday     2                 0
# 111  device_3    Monday     3                 0
# 112  device_3    Monday     4                 0
# 113  device_3    Monday     5                 0
# 114  device_3    Monday     6                 0
# 115  device_3    Monday     7                 0
# 116  device_3    Monday     8                 1
# 117  device_3    Monday     9                 1
# 118  device_3    Monday    10                 1
# 119  device_3    Monday    11                 1
# 120  device_3    Monday    12                 1
# 121  device_3    Monday    13                 1
# 122  device_3    Monday    14                 1
# 123  device_3    Monday    15                 1
# 124  device_3    Monday    16                 1
# 125  device_3    Monday    17                 1
# 126  device_3    Monday    18                 1
# 127  device_3    Monday    19                 1
# 128  device_3  Saturday     0                 0
# 129  device_3  Saturday     1                 0
# 130  device_3  Saturday     2                 0
# 131  device_3  Saturday     3                 0
# 132  device_3  Saturday     4                 0
# 133  device_3  Saturday     5                 0
# 134  device_3  Saturday     6                 0
# 135  device_3  Saturday     7                 0
# 136  device_3  Saturday     8                 0
# 137  device_3  Saturday     9                 0
# 138  device_3  Saturday    10                 0
# 139  device_3  Saturday    11                 0
# 140  device_3  Saturday    12                 0
# 141  device_3  Saturday    13                 0
# 142  device_3  Saturday    14                 0
# 143  device_3  Saturday    15                 0
# 144  device_3  Saturday    16                 0
# 145  device_3  Saturday    17                 0
# 146  device_3  Saturday    18                 0
# 147  device_3  Saturday    19                 0
# 148  device_3  Saturday    20                 0
# 149  device_3  Saturday    21                 0
# 150  device_3  Saturday    22                 0
# 151  device_3  Saturday    23                 0
# 152  device_3    Sunday     0                 0
# 153  device_3    Sunday     1                 0
# 154  device_3    Sunday     2                 0
# 155  device_3    Sunday     3                 0
# 156  device_3    Sunday     4                 0
# 157  device_3    Sunday     5                 0
# 158  device_3    Sunday     6                 0
# 159  device_3    Sunday     7                 0
# 160  device_3    Sunday     8                 0
# 161  device_3    Sunday     9                 0
# 162  device_3    Sunday    10                 0
# 163  device_3    Sunday    11                 0
# 164  device_3    Sunday    12                 0
# 165  device_3    Sunday    13                 0
# 166  device_3    Sunday    14                 0
# 167  device_3    Sunday    15                 0
# 168  device_3    Sunday    16                 0
# 169  device_3    Sunday    17                 0
# 170  device_3    Sunday    18                 0
# 171  device_3    Sunday    19                 0
# 172  device_3    Sunday    20                 1
# 173  device_3    Sunday    21                 0
# 174  device_3    Sunday    22                 0
# 175  device_3    Sunday    23                 0
# 176  device_4    Friday     4                 0
# 177  device_4    Friday     5                 0
# 178  device_4    Friday     6                 0
# 179  device_4    Friday     7                 1
# 180  device_4    Friday     8                 1
# 181  device_4    Friday     9                 0
# 182  device_4    Friday    10                 0
# 183  device_4    Friday    11                 0
# 184  device_4    Friday    12                 0
# 185  device_4    Friday    13                 0
# 186  device_4    Friday    14                 0
# 187  device_4    Friday    15                 0
# 188  device_4    Friday    16                 0
# 189  device_4    Friday    17                 0
# 190  device_4    Friday    18                 0
# 191  device_4    Friday    19                 0
# 192  device_4    Friday    20                 0
# 193  device_4    Friday    21                 0
# 194  device_4    Friday    22                 0
# 195  device_4    Friday    23                 0
# 196  device_4    Monday     0                 0
# 197  device_4    Monday     1                 0
# 198  device_4    Monday     2                 0
# 199  device_4    Monday     3                 0
# 200  device_4    Monday     4                 0
# 201  device_4    Monday     5                 0
# 202  device_4    Monday     6                 0
# 203  device_4    Monday     7                 0
# 204  device_4    Monday     8                 0
# 205  device_4    Monday     9                 0
# 206  device_4    Monday    10                 0
# 207  device_4    Monday    11                 0
# 208  device_4    Monday    12                 1
# 209  device_4    Monday    13                 1
# 210  device_4    Monday    14                 1
# 211  device_4    Monday    15                 1
# 212  device_4    Monday    16                 1
# 213  device_4    Monday    17                 1
# 214  device_4    Monday    18                 0
# 215  device_4    Monday    19                 0
# 216  device_4  Saturday     0                 0
# 217  device_4  Saturday     1                 0
# 218  device_4  Saturday     2                 0
# 219  device_4  Saturday     3                 0
# 220  device_4  Saturday     4                 0
# 221  device_4  Saturday     5                 0
# 222  device_4  Saturday     6                 0
# 223  device_4  Saturday     7                 0
# 224  device_4  Saturday     8                 0
# 225  device_4  Saturday     9                 0
# 226  device_4  Saturday    10                 0
# 227  device_4  Saturday    11                 0
# 228  device_4  Saturday    12                 0
# 229  device_4  Saturday    13                 0
# 230  device_4  Saturday    14                 0
# 231  device_4  Saturday    15                 0
# 232  device_4  Saturday    16                 0
# 233  device_4  Saturday    17                 0
# 234  device_4  Saturday    18                 0
# 235  device_4  Saturday    19                 0
# 236  device_4  Saturday    20                 0
# 237  device_4  Saturday    21                 0
# 238  device_4  Saturday    22                 0
# 239  device_4  Saturday    23                 0
# 240  device_4    Sunday     0                 0
# 241  device_4    Sunday     1                 0
# 242  device_4    Sunday     2                 0
# 243  device_4    Sunday     3                 0
# 244  device_4    Sunday     4                 0
# 245  device_4    Sunday     5                 0
# 246  device_4    Sunday     6                 0
# 247  device_4    Sunday     7                 0
# 248  device_4    Sunday     8                 0
# 249  device_4    Sunday     9                 0
# 250  device_4    Sunday    10                 0
# 251  device_4    Sunday    11                 0
# 252  device_4    Sunday    12                 0
# 253  device_4    Sunday    13                 0
# 254  device_4    Sunday    14                 0
# 255  device_4    Sunday    15                 0
# 256  device_4    Sunday    16                 0
# 257  device_4    Sunday    17                 0
# 258  device_4    Sunday    18                 0
# 259  device_4    Sunday    19                 0
# 260  device_4    Sunday    20                 0
# 261  device_4    Sunday    21                 0
# 262  device_4    Sunday    22                 0
# 263  device_4    Sunday    23                 0
# 264  device_5    Friday     4                 0
# 265  device_5    Friday     5                 0
# 266  device_5    Friday     6                 0
# 267  device_5    Friday     7                 0
# 268  device_5    Friday     8                 1
# 269  device_5    Friday     9                 0
# 270  device_5    Friday    10                 0
# 271  device_5    Friday    11                 0
# 272  device_5    Friday    12                 0
# 273  device_5    Friday    13                 0
# 274  device_5    Friday    14                 0
# 275  device_5    Friday    15                 0
# 276  device_5    Friday    16                 0
# 277  device_5    Friday    17                 0
# 278  device_5    Friday    18                 0
# 279  device_5    Friday    19                 0
# 280  device_5    Friday    20                 0
# 281  device_5    Friday    21                 0
# 282  device_5    Friday    22                 0
# 283  device_5    Friday    23                 0
# 284  device_5    Monday     0                 0
# 285  device_5    Monday     1                 0
# 286  device_5    Monday     2                 0
# 287  device_5    Monday     3                 0
# 288  device_5    Monday     4                 0
# 289  device_5    Monday     5                 0
# 290  device_5    Monday     6                 0
# 291  device_5    Monday     7                 0
# 292  device_5    Monday     8                 0
# 293  device_5    Monday     9                 0
# 294  device_5    Monday    10                 0
# 295  device_5    Monday    11                 0
# 296  device_5    Monday    12                 1
# 297  device_5    Monday    13                 1
# 298  device_5    Monday    14                 1
# 299  device_5    Monday    15                 1
# 300  device_5    Monday    16                 1
# 301  device_5    Monday    17                 0
# 302  device_5    Monday    18                 0
# 303  device_5    Monday    19                 0
# 304  device_5  Saturday     0                 0
# 305  device_5  Saturday     1                 0
# 306  device_5  Saturday     2                 0
# 307  device_5  Saturday     3                 0
# 308  device_5  Saturday     4                 0
# 309  device_5  Saturday     5                 0
# 310  device_5  Saturday     6                 0
# 311  device_5  Saturday     7                 0
# 312  device_5  Saturday     8                 0
# 313  device_5  Saturday     9                 0
# 314  device_5  Saturday    10                 0
# 315  device_5  Saturday    11                 0
# 316  device_5  Saturday    12                 0
# 317  device_5  Saturday    13                 0
# 318  device_5  Saturday    14                 0
# 319  device_5  Saturday    15                 0
# 320  device_5  Saturday    16                 0
# 321  device_5  Saturday    17                 0
# 322  device_5  Saturday    18                 0
# 323  device_5  Saturday    19                 0
# 324  device_5  Saturday    20                 0
# 325  device_5  Saturday    21                 0
# 326  device_5  Saturday    22                 0
# 327  device_5  Saturday    23                 0
# 328  device_5    Sunday     0                 0
# 329  device_5    Sunday     1                 0
# 330  device_5    Sunday     2                 0
# 331  device_5    Sunday     3                 0
# 332  device_5    Sunday     4                 0
# 333  device_5    Sunday     5                 0
# 334  device_5    Sunday     6                 0
# 335  device_5    Sunday     7                 0
# 336  device_5    Sunday     8                 0
# 337  device_5    Sunday     9                 0
# 338  device_5    Sunday    10                 0
# 339  device_5    Sunday    11                 0
# 340  device_5    Sunday    12                 0
# 341  device_5    Sunday    13                 0
# 342  device_5    Sunday    14                 0
# 343  device_5    Sunday    15                 0
# 344  device_5    Sunday    16                 0
# 345  device_5    Sunday    17                 0
# 346  device_5    Sunday    18                 0
# 347  device_5    Sunday    19                 0
# 348  device_5    Sunday    20                 0
# 349  device_5    Sunday    21                 0
# 350  device_5    Sunday    22                 0
# 351  device_5    Sunday    23                 0
# 352  device_6    Friday     4                 1
# 353  device_6    Friday     5                 0
# 354  device_6    Friday     6                 0
# 355  device_6    Friday     7                 1
# 356  device_6    Friday     8                 1
# 357  device_6    Friday     9                 0
# 358  device_6    Friday    10                 0
# 359  device_6    Friday    11                 0
# 360  device_6    Friday    12                 0
# 361  device_6    Friday    13                 0
# 362  device_6    Friday    14                 0
# 363  device_6    Friday    15                 0
# 364  device_6    Friday    16                 0
# 365  device_6    Friday    17                 0
# 366  device_6    Friday    18                 0
# 367  device_6    Friday    19                 0
# 368  device_6    Friday    20                 0
# 369  device_6    Friday    21                 0
# 370  device_6    Friday    22                 0
# 371  device_6    Friday    23                 0
# 372  device_6    Monday     0                 0
# 373  device_6    Monday     1                 0
# 374  device_6    Monday     2                 0
# 375  device_6    Monday     3                 0
# 376  device_6    Monday     4                 0
# 377  device_6    Monday     5                 0
# 378  device_6    Monday     6                 0
# 379  device_6    Monday     7                 0
# 380  device_6    Monday     8                 0
# 381  device_6    Monday     9                 0
# 382  device_6    Monday    10                 0
# 383  device_6    Monday    11                 0
# 384  device_6    Monday    12                 1
# 385  device_6    Monday    13                 1
# 386  device_6    Monday    14                 1
# 387  device_6    Monday    15                 1
# 388  device_6    Monday    16                 1
# 389  device_6    Monday    17                 1
# 390  device_6    Monday    18                 1
# 391  device_6    Monday    19                 0
# 392  device_6  Saturday     0                 0
# 393  device_6  Saturday     1                 0
# 394  device_6  Saturday     2                 0
# 395  device_6  Saturday     3                 0
# 396  device_6  Saturday     4                 0
# 397  device_6  Saturday     5                 0
# 398  device_6  Saturday     6                 0
# 399  device_6  Saturday     7                 0
# 400  device_6  Saturday     8                 0
# 401  device_6  Saturday     9                 0
# 402  device_6  Saturday    10                 0
# 403  device_6  Saturday    11                 0
# 404  device_6  Saturday    12                 0
# 405  device_6  Saturday    13                 0
# 406  device_6  Saturday    14                 0
# 407  device_6  Saturday    15                 0
# 408  device_6  Saturday    16                 0
# 409  device_6  Saturday    17                 0
# 410  device_6  Saturday    18                 0
# 411  device_6  Saturday    19                 0
# 412  device_6  Saturday    20                 0
# 413  device_6  Saturday    21                 0
# 414  device_6  Saturday    22                 0
# 415  device_6  Saturday    23                 0
# 416  device_6    Sunday     0                 0
# 417  device_6    Sunday     1                 0
# 418  device_6    Sunday     2                 0
# 419  device_6    Sunday     3                 0
# 420  device_6    Sunday     4                 0
# 421  device_6    Sunday     5                 0
# 422  device_6    Sunday     6                 0
# 423  device_6    Sunday     7                 0
# 424  device_6    Sunday     8                 0
# 425  device_6    Sunday     9                 0
# 426  device_6    Sunday    10                 0
# 427  device_6    Sunday    11                 0
# 428  device_6    Sunday    12                 0
# 429  device_6    Sunday    13                 0
# 430  device_6    Sunday    14                 0
# 431  device_6    Sunday    15                 0
# 432  device_6    Sunday    16                 0
# 433  device_6    Sunday    17                 0
# 434  device_6    Sunday    18                 0
# 435  device_6    Sunday    19                 0
# 436  device_6    Sunday    20                 0
# 437  device_6    Sunday    21                 0
# 438  device_6    Sunday    22                 0
# 439  device_6    Sunday    23                 0
# 440  device_7    Friday     4                 0
# 441  device_7    Friday     5                 0
# 442  device_7    Friday     6                 0
# 443  device_7    Friday     7                 0
# 444  device_7    Friday     8                 0
# 445  device_7    Friday     9                 0
# 446  device_7    Friday    10                 0
# 447  device_7    Friday    11                 0
# 448  device_7    Friday    12                 0
# 449  device_7    Friday    13                 0
# 450  device_7    Friday    14                 0
# 451  device_7    Friday    15                 0
# 452  device_7    Friday    16                 0
# 453  device_7    Friday    17                 0
# 454  device_7    Friday    18                 0
# 455  device_7    Friday    19                 0
# 456  device_7    Friday    20                 0
# 457  device_7    Friday    21                 0
# 458  device_7    Friday    22                 0
# 459  device_7    Friday    23                 0
# 460  device_7    Monday     0                 0
# 461  device_7    Monday     1                 0
# 462  device_7    Monday     2                 0
# 463  device_7    Monday     3                 0
# 464  device_7    Monday     4                 0
# 465  device_7    Monday     5                 0
# 466  device_7    Monday     6                 0
# 467  device_7    Monday     7                 0
# 468  device_7    Monday     8                 0
# 469  device_7    Monday     9                 0
# 470  device_7    Monday    10                 0
# 471  device_7    Monday    11                 0
# 472  device_7    Monday    12                 0
# 473  device_7    Monday    13                 0
# 474  device_7    Monday    14                 1
# 475  device_7    Monday    15                 1
# 476  device_7    Monday    16                 1
# 477  device_7    Monday    17                 0
# 478  device_7    Monday    18                 0
# 479  device_7    Monday    19                 0
# 480  device_7  Saturday     0                 0
# 481  device_7  Saturday     1                 0
# 482  device_7  Saturday     2                 0
# 483  device_7  Saturday     3                 0
# 484  device_7  Saturday     4                 0
# 485  device_7  Saturday     5                 0
# 486  device_7  Saturday     6                 0
# 487  device_7  Saturday     7                 0
# 488  device_7  Saturday     8                 0
# 489  device_7  Saturday     9                 0
# 490  device_7  Saturday    10                 0
# 491  device_7  Saturday    11                 0
# 492  device_7  Saturday    12                 0
# 493  device_7  Saturday    13                 0
# 494  device_7  Saturday    14                 0
# 495  device_7  Saturday    15                 0
# 496  device_7  Saturday    16                 0
# 497  device_7  Saturday    17                 0
# 498  device_7  Saturday    18                 0
# 499  device_7  Saturday    19                 0
# 500  device_7  Saturday    20                 0
# 501  device_7  Saturday    21                 0
# 502  device_7  Saturday    22                 0
# 503  device_7  Saturday    23                 0
# 504  device_7    Sunday     0                 0
# 505  device_7    Sunday     1                 0
# 506  device_7    Sunday     2                 0
# 507  device_7    Sunday     3                 0
# 508  device_7    Sunday     4                 0
# 509  device_7    Sunday     5                 0
# 510  device_7    Sunday     6                 0
# 511  device_7    Sunday     7                 0
# 512  device_7    Sunday     8                 0
# 513  device_7    Sunday     9                 0
# 514  device_7    Sunday    10                 0
# 515  device_7    Sunday    11                 0
# 516  device_7    Sunday    12                 0
# 517  device_7    Sunday    13                 0
# 518  device_7    Sunday    14                 0
# 519  device_7    Sunday    15                 0
# 520  device_7    Sunday    16                 0
# 521  device_7    Sunday    17                 0
# 522  device_7    Sunday    18                 0
# 523  device_7    Sunday    19                 0
# 524  device_7    Sunday    20                 0
# 525  device_7    Sunday    21                 0
# 526  device_7    Sunday    22                 0
# 527  device_7    Sunday    23                 0

# %%
pred
# Out:
#                    time    device day_name  hour  device_activated
# 0   2016-07-05 00:00:00  device_1  Tuesday     0               0.0
# 1   2016-07-05 00:00:00  device_2  Tuesday     0               0.0
# 2   2016-07-05 00:00:00  device_3  Tuesday     0               0.0
# 3   2016-07-05 00:00:00  device_4  Tuesday     0               0.0
# 4   2016-07-05 00:00:00  device_5  Tuesday     0               0.0
# 5   2016-07-05 00:00:00  device_6  Tuesday     0               0.0
# 6   2016-07-05 00:00:00  device_7  Tuesday     0               0.0
# 7   2016-07-05 01:00:00  device_1  Tuesday     1               0.0
# 8   2016-07-05 01:00:00  device_2  Tuesday     1               0.0
# 9   2016-07-05 01:00:00  device_3  Tuesday     1               0.0
# 10  2016-07-05 01:00:00  device_4  Tuesday     1               0.0
# 11  2016-07-05 01:00:00  device_5  Tuesday     1               0.0
# 12  2016-07-05 01:00:00  device_6  Tuesday     1               0.0
# 13  2016-07-05 01:00:00  device_7  Tuesday     1               0.0
# 14  2016-07-05 02:00:00  device_1  Tuesday     2               0.0
# 15  2016-07-05 02:00:00  device_2  Tuesday     2               0.0
# 16  2016-07-05 02:00:00  device_3  Tuesday     2               0.0
# 17  2016-07-05 02:00:00  device_4  Tuesday     2               0.0
# 18  2016-07-05 02:00:00  device_5  Tuesday     2               0.0
# 19  2016-07-05 02:00:00  device_6  Tuesday     2               0.0
# 20  2016-07-05 02:00:00  device_7  Tuesday     2               0.0
# 21  2016-07-05 03:00:00  device_1  Tuesday     3               0.0
# 22  2016-07-05 03:00:00  device_2  Tuesday     3               0.0
# 23  2016-07-05 03:00:00  device_3  Tuesday     3               0.0
# 24  2016-07-05 03:00:00  device_4  Tuesday     3               0.0
# 25  2016-07-05 03:00:00  device_5  Tuesday     3               0.0
# 26  2016-07-05 03:00:00  device_6  Tuesday     3               0.0
# 27  2016-07-05 03:00:00  device_7  Tuesday     3               0.0
# 28  2016-07-05 04:00:00  device_1  Tuesday     4               0.0
# 29  2016-07-05 04:00:00  device_2  Tuesday     4               0.0
# 30  2016-07-05 04:00:00  device_3  Tuesday     4               0.0
# 31  2016-07-05 04:00:00  device_4  Tuesday     4               0.0
# 32  2016-07-05 04:00:00  device_5  Tuesday     4               0.0
